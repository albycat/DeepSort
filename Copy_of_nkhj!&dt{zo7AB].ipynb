# %% [markdown]
# <a href="https://colab.research.google.com/github/albycat/DeepSort/blob/master/Copy_of_nkhj!%26dt%7Bzo7AB%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%html
# <audio src="https://henk.tech/colabkobold/silence.m4a" controls>

# %%
Model = "vKUFUzrUTxZmKaL"
Version = "Official"
KoboldAI_Provider = "Localtunnel" #@param ["Localtunnel", "Cloudflare"]
use_google_drive = False #@param {type:"boolean"}
Provider = KoboldAI_Provider
# !nvidia-smi
import subprocess
import time
import sys
import os
import threading
import shutil
from google.colab import drive


if use_google_drive:
  drive.mount('/content/drive/')
  if not os.path.exists("/content/drive/MyDrive/TavernAI/"):
    os.mkdir("/content/drive/MyDrive/TavernAI/")
  if not os.path.exists("/content/drive/MyDrive/TavernAI/characters/"):
    os.mkdir("/content/drive/MyDrive/TavernAI/characters/")
  if not os.path.exists("/content/drive/MyDrive/TavernAI/chats/"):
    os.mkdir("/content/drive/MyDrive/TavernAI/chats/")
else:
  if not os.path.exists("/content/drive"):
    os.mkdir("/content/drive")
  if not os.path.exists("/content/drive/MyDrive/"):
    os.mkdir("/content/drive/MyDrive/")

def copy_characters(use_google_drive=False):
  if not use_google_drive:
    return

  src_folder = "/TavernAIColab/public/characters"
  dst_folder = "/content/drive/MyDrive/TavernAI/characters"

  for filename in os.listdir(src_folder):
    src_file = os.path.join(src_folder, filename)
    dst_file = os.path.join(dst_folder, filename)

    if os.path.exists(dst_file):
      print(f"{dst_file} already exists. Skipping...")
      continue

    shutil.copy(src_file, dst_folder)
    print(f"{src_file} copied to {dst_folder}")
Revision = ""

if Model == "vKUFUzrUTxZmKaL":
  Model = "vlrfrwaprnyysf1/vKUFUzrUTxZmKaL"
  path = ""
  download = ""
  Version = "United"

if Provider == "Localtunnel":
  tunnel = "--localtunnel yes"
else:
  tunnel = ""


# !wget https://koboldai.org/ckds && chmod +x ckds
# !./ckds --init only
if Provider == "Localtunnel":
  p = subprocess.Popen(['/content/ckds', '--model', Model, '--localtunnel', 'yes'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
else:
  p = subprocess.Popen(['/content/ckds', '--model', Model], stdout=subprocess.PIPE, stderr=subprocess.PIPE)


url = ''
while True:
    line = p.stdout.readline().decode().strip()
    if "KoboldAI has finished loading and is available at the following link: " in line:
        print(line)
        url = line.split("KoboldAI has finished loading and is available at the following link: ")[1]
        print(url)
        break
    if "KoboldAI has finished loading and is available at the following link for UI 1: " in line:
        print(line)
        url = line.split("KoboldAI has finished loading and is available at the following link for UI 1: ")[1]
        print(url)
        break
    if not line:
        break
    print(line)
    if "INIT" in line and "Transformers" in line:
      print("Model loading... (It will take 2 - 5 minutes)")


# %cd /
# !curl -o- https://raw.githubusercontent.com/nvm-sh/nvm/v0.37.2/install.sh | bash
# !nvm install 19.1.0
# !nvm use 19.1.0
# !node -v
# !git clone https://github.com/TavernAI/TavernAIColab
copy_characters(use_google_drive)
# %cd TavernAIColab
# !npm install
time.sleep(1)
# %env colab=2
# %env colaburl=$url
if use_google_drive:
  # %env googledrive=2
# !nohup node server.js &
time.sleep(3)
print('KoboldAI LINK:')
print(url)
print('')
print('###TavernAI LINK###')
# !lt --port 8000
# Out:
# Fri Sep  1 17:05:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# --2023-09-01 17:05:19--  https://koboldai.org/ckds
# Resolving koboldai.org (koboldai.org)... 172.67.199.170, 104.21.21.176, 2606:4700:3036::ac43:c7aa, ...
# Connecting to koboldai.org (koboldai.org)|172.67.199.170|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://raw.githubusercontent.com/henk717/KoboldAI/united/colabkobold.sh [following]
# --2023-09-01 17:05:19--  https://raw.githubusercontent.com/henk717/KoboldAI/united/colabkobold.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6825 (6.7K) [text/plain]
# Saving to: ‘ckds’
#
# ckds                100%[===================>]   6.67K  --.-KB/s    in 0s
#
# 2023-09-01 17:05:20 (87.7 MB/s) - ‘ckds’ saved [6825/6825]
#
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/KoboldAI-Client/.git/
# error: No such remote: 'origin'
# Fetching origin
# remote: Enumerating objects: 6653, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6653 (delta 0), reused 1 (delta 0), pack-reused 6649
# Receiving objects: 100% (6653/6653), 14.10 MiB | 16.88 MiB/s, done.
# Resolving deltas: 100% (4191/4191), done.
# From https://github.com/koboldai/KoboldAI-Client
#  * [new branch]      main       -> origin/main
#  * [new tag]         1.18.2     -> 1.18.2
#  * [new tag]         1.19.0     -> 1.19.0
#  * [new tag]         1.19.1     -> 1.19.1
#  * [new tag]         1.19.2     -> 1.19.2
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Switched to a new branch 'main'
# HEAD is now at d86f611 Working revision support
# cp: cannot stat 'softprompts/*': No such file or directory
# cp: cannot stat 'presets/*': No such file or directory
# cp: cannot stat 'themes/*': No such file or directory
# rm: cannot remove 'stories': Is a directory
# rm: cannot remove 'userscripts': Is a directory
# rm: cannot remove 'softprompts': No such file or directory
# rm: cannot remove 'models': Is a directory
# rm: cannot remove 'presets': No such file or directory
# rm: cannot remove 'themes': No such file or directory
# Collecting git+https://github.com/VE-FORBRYDERNE/mkultra (from -r requirements.txt (line 24))
#   Cloning https://github.com/VE-FORBRYDERNE/mkultra to /tmp/pip-req-build-06o_xx8u
#   Running command git clone --filter=blob:none --quiet https://github.com/VE-FORBRYDERNE/mkultra /tmp/pip-req-build-06o_xx8u
#   Resolved https://github.com/VE-FORBRYDERNE/mkultra to commit ef544de73ec6a1a4bd55e824d0628fa0ef1323ac
#   Preparing metadata (setup.py) ... done
# Collecting transformers==4.24.0 (from -r requirements.txt (line 1))
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 18.1 MB/s eta 0:00:00
# Collecting huggingface_hub==0.12.1 (from -r requirements.txt (line 2))
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 kB 21.6 MB/s eta 0:00:00
# Collecting Flask==2.2.3 (from -r requirements.txt (line 3))
#   Downloading Flask-2.2.3-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 12.8 MB/s eta 0:00:00
# Collecting Flask-SocketIO==5.3.2 (from -r requirements.txt (line 4))
#   Downloading Flask_SocketIO-5.3.2-py3-none-any.whl (17 kB)
# Collecting python-socketio==5.7.2 (from -r requirements.txt (line 5))
#   Downloading python_socketio-5.7.2-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (2.31.0)
# Collecting torch<1.13,>=1.9 (from -r requirements.txt (line 7))
#   Downloading torch-1.12.1-cp310-cp310-manylinux1_x86_64.whl (776.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 2.2 MB/s eta 0:00:00
# Collecting flask-cloudflared==0.0.10 (from -r requirements.txt (line 8))
#   Downloading flask_cloudflared-0.0.10-py3-none-any.whl (5.9 kB)
# Collecting flask-ngrok (from -r requirements.txt (line 9))
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Collecting eventlet==0.33.3 (from -r requirements.txt (line 10))
#   Downloading eventlet-0.33.3-py2.py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 25.1 MB/s eta 0:00:00
# Collecting dnspython==2.2.1 (from -r requirements.txt (line 11))
#   Downloading dnspython-2.2.1-py3-none-any.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 kB 32.1 MB/s eta 0:00:00
# Collecting lupa==1.10 (from -r requirements.txt (line 12))
#   Downloading lupa-1.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 76.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 13)) (3.4.4)
# Collecting bleach==4.1.0 (from -r requirements.txt (line 14))
#   Downloading bleach-4.1.0-py2.py3-none-any.whl (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.9/157.9 kB 18.2 MB/s eta 0:00:00
# Collecting sentencepiece (from -r requirements.txt (line 15))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.9 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 16)) (3.20.3)
# Collecting accelerate (from -r requirements.txt (line 17))
#   Downloading accelerate-0.22.0-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 27.9 MB/s eta 0:00:00
# Collecting flask-session==0.4.0 (from -r requirements.txt (line 18))
#   Downloading Flask_Session-0.4.0-py2.py3-none-any.whl (7.5 kB)
# Collecting marshmallow>=3.13 (from -r requirements.txt (line 19))
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.7 MB/s eta 0:00:00
# Collecting apispec-webframeworks (from -r requirements.txt (line 20))
#   Downloading apispec_webframeworks-0.5.2-py2.py3-none-any.whl (12 kB)
# Collecting loguru (from -r requirements.txt (line 21))
#   Downloading loguru-0.7.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 22)) (2.3.0)
# Collecting safetensors (from -r requirements.txt (line 23))
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (3.12.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.24.0->-r requirements.txt (line 1))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.12.1->-r requirements.txt (line 2)) (4.7.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (2.3.7)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (8.1.7)
# Collecting bidict>=0.21.0 (from python-socketio==5.7.2->-r requirements.txt (line 5))
#   Downloading bidict-0.22.1-py3-none-any.whl (35 kB)
# Collecting python-engineio>=4.3.0 (from python-socketio==5.7.2->-r requirements.txt (line 5))
#   Downloading python_engineio-4.6.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: greenlet>=0.3 in /usr/local/lib/python3.10/dist-packages (from eventlet==0.33.3->-r requirements.txt (line 10)) (2.0.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from eventlet==0.33.3->-r requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach==4.1.0->-r requirements.txt (line 14)) (0.5.1)
# Collecting cachelib (from flask-session==0.4.0->-r requirements.txt (line 18))
#   Downloading cachelib-0.10.2-py3-none-any.whl (18 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 6)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 6)) (2023.7.22)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 17)) (5.9.5)
# Collecting apispec[yaml]>=2.0.0 (from apispec-webframeworks->-r requirements.txt (line 20))
#   Downloading apispec-6.3.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->Flask==2.2.3->-r requirements.txt (line 3)) (2.1.3)
# Building wheels for collected packages: lupa, mkultra
#   Building wheel for lupa (setup.py) ... done
#   Created wheel for lupa: filename=lupa-1.10-cp310-cp310-linux_x86_64.whl size=1101135 sha256=2c192f98c97afe66e46b09ee36c927c270bdee2e1843d6cf1a7f8aacc6bb9ddc
#   Stored in directory: /root/.cache/pip/wheels/93/a3/25/eec3aaca044bc9ffd3a960dcaa92d4beaf874654b5cf632443
#   Building wheel for mkultra (setup.py) ... done
#   Created wheel for mkultra: filename=mkultra-0.1-py3-none-any.whl size=10898 sha256=1d85d100f0e98c5011c2fd51ca67a7c0d876aee79d52c594b35ad29612c70770
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sy11ctub/wheels/1f/63/2e/bb2431c68bc2d4121376a2881f80f74f35e21ec6d0418b8b05
# Successfully built lupa mkultra
# Installing collected packages: tokenizers, sentencepiece, safetensors, mkultra, lupa, torch, python-engineio, marshmallow, loguru, dnspython, cachelib, bleach, bidict, apispec, python-socketio, huggingface_hub, Flask, eventlet, accelerate, transformers, Flask-SocketIO, flask-session, flask-ngrok, flask-cloudflared, apispec-webframeworks
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
# ERROR: Operation cancelled by user
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2 netbase
# 0 upgraded, 4 newly installed, 0 to remove and 16 not upgraded.
# Need to get 1,526 kB of archives.
# After this operation, 5,482 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 netbase all 6.3 [12.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.2 [45.0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libaria2-0 amd64 1.36.0-1 [1,086 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 aria2 amd64 1.36.0-1 [381 kB]
# Fetched 1,526 kB in 1s (2,394 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package netbase.
# (Reading database ... 120893 files and directories currently installed.)
# Preparing to unpack .../archives/netbase_6.3_all.deb ...
# Unpacking netbase (6.3) ...
# Selecting previously unselected package libc-ares2:amd64.
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.2_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Setting up netbase (6.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# added 22 packages from 22 contributors in 2.873s
# Initialization complete...
# Reinitialized existing Git repository in /content/KoboldAI-Client/.git/
# Fetching origin
# HEAD is now at d86f611 Working revision support
# Collecting git+https://github.com/VE-FORBRYDERNE/mkultra (from -r requirements.txt (line 24))
# Cloning https://github.com/VE-FORBRYDERNE/mkultra to /tmp/pip-req-build-xu_jf0b2
# Resolved https://github.com/VE-FORBRYDERNE/mkultra to commit ef544de73ec6a1a4bd55e824d0628fa0ef1323ac
# Preparing metadata (setup.py): started
# Preparing metadata (setup.py): finished with status 'done'
# Collecting transformers==4.24.0 (from -r requirements.txt (line 1))
# Using cached transformers-4.24.0-py3-none-any.whl (5.5 MB)
# Collecting huggingface_hub==0.12.1 (from -r requirements.txt (line 2))
# Using cached huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
# Collecting Flask==2.2.3 (from -r requirements.txt (line 3))
# Using cached Flask-2.2.3-py3-none-any.whl (101 kB)
# Collecting Flask-SocketIO==5.3.2 (from -r requirements.txt (line 4))
# Using cached Flask_SocketIO-5.3.2-py3-none-any.whl (17 kB)
# Collecting python-socketio==5.7.2 (from -r requirements.txt (line 5))
# Using cached python_socketio-5.7.2-py3-none-any.whl (56 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (2.31.0)
# Collecting torch<1.13,>=1.9 (from -r requirements.txt (line 7))
# Using cached torch-1.12.1-cp310-cp310-manylinux1_x86_64.whl (776.3 MB)
# Collecting flask-cloudflared==0.0.10 (from -r requirements.txt (line 8))
# Using cached flask_cloudflared-0.0.10-py3-none-any.whl (5.9 kB)
# Collecting flask-ngrok (from -r requirements.txt (line 9))
# Using cached flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Collecting eventlet==0.33.3 (from -r requirements.txt (line 10))
# Using cached eventlet-0.33.3-py2.py3-none-any.whl (226 kB)
# Collecting dnspython==2.2.1 (from -r requirements.txt (line 11))
# Using cached dnspython-2.2.1-py3-none-any.whl (269 kB)
# Requirement already satisfied: lupa==1.10 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 12)) (1.10)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 13)) (3.4.4)
# Collecting bleach==4.1.0 (from -r requirements.txt (line 14))
# Using cached bleach-4.1.0-py2.py3-none-any.whl (157 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 15)) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 16)) (3.20.3)
# Collecting accelerate (from -r requirements.txt (line 17))
# Using cached accelerate-0.22.0-py3-none-any.whl (251 kB)
# Collecting flask-session==0.4.0 (from -r requirements.txt (line 18))
# Using cached Flask_Session-0.4.0-py2.py3-none-any.whl (7.5 kB)
# Collecting marshmallow>=3.13 (from -r requirements.txt (line 19))
# Using cached marshmallow-3.20.1-py3-none-any.whl (49 kB)
# Collecting apispec-webframeworks (from -r requirements.txt (line 20))
# Using cached apispec_webframeworks-0.5.2-py2.py3-none-any.whl (12 kB)
# Collecting loguru (from -r requirements.txt (line 21))
# Using cached loguru-0.7.0-py3-none-any.whl (59 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 22)) (2.3.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 23)) (0.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (3.12.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 1)) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.12.1->-r requirements.txt (line 2)) (4.7.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (2.3.7)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (8.1.7)
# Collecting bidict>=0.21.0 (from python-socketio==5.7.2->-r requirements.txt (line 5))
# Using cached bidict-0.22.1-py3-none-any.whl (35 kB)
# Collecting python-engineio>=4.3.0 (from python-socketio==5.7.2->-r requirements.txt (line 5))
# Using cached python_engineio-4.6.1-py3-none-any.whl (53 kB)
# Requirement already satisfied: greenlet>=0.3 in /usr/local/lib/python3.10/dist-packages (from eventlet==0.33.3->-r requirements.txt (line 10)) (2.0.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from eventlet==0.33.3->-r requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach==4.1.0->-r requirements.txt (line 14)) (0.5.1)
# Collecting cachelib (from flask-session==0.4.0->-r requirements.txt (line 18))
# Using cached cachelib-0.10.2-py3-none-any.whl (18 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 6)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 6)) (2023.7.22)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->-r requirements.txt (line 17)) (5.9.5)
# Collecting apispec[yaml]>=2.0.0 (from apispec-webframeworks->-r requirements.txt (line 20))
# Using cached apispec-6.3.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->Flask==2.2.3->-r requirements.txt (line 3)) (2.1.3)
# Installing collected packages: torch, python-engineio, marshmallow, loguru, dnspython, cachelib, bleach, bidict, apispec, python-socketio, huggingface_hub, Flask, eventlet, accelerate, transformers, Flask-SocketIO, flask-session, flask-ngrok, flask-cloudflared, apispec-webframeworks
# Attempting uninstall: bleach
# Found existing installation: bleach 6.0.0
# Uninstalling bleach-6.0.0:
# Successfully uninstalled bleach-6.0.0
# Attempting uninstall: Flask
# Found existing installation: Flask 2.2.5
# Uninstalling Flask-2.2.5:
# Successfully uninstalled Flask-2.2.5
# Successfully installed Flask-2.2.3 Flask-SocketIO-5.3.2 accelerate-0.22.0 apispec-6.3.0 apispec-webframeworks-0.5.2 bidict-0.22.1 bleach-4.1.0 cachelib-0.10.2 dnspython-2.2.1 eventlet-0.33.3 flask-cloudflared-0.0.10 flask-ngrok-0.0.25 flask-session-0.4.0 huggingface_hub-0.12.1 loguru-0.7.0 marshmallow-3.20.1 python-engineio-4.6.1 python-socketio-5.7.2 torch-1.12.1 transformers-4.24.0
# Reading package lists...
# Building dependency tree...
# Reading state information...
# netbase is already the newest version (6.3).
# aria2 is already the newest version (1.36.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# updated 1 package in 0.743s
# Launching KoboldAI with the following options : python3 aiserver.py --model vlrfrwaprnyysf1/vKUFUzrUTxZmKaL --localtunnel --colab
# MESSAGE    | Welcome to KoboldAI!
# MESSAGE    | You have selected the following Model: vlrfrwaprnyysf1/vKUFUzrUTxZmKaL
# INIT       | Starting   | Flask
# INIT       | OK         | Flask
# INIT       | Starting   | Webserver
# INIT       | Searching  | GPU support
# INIT       | Found      | GPU support
# INIT       | Starting   | Transformers
# Model loading... (It will take 2 - 5 minutes)
